# %% [markdown]
# # Python Program to read iris dataset and learn how to form a Decision Tree
# # Submited by Sandesh S
# # The Spark Foundation Internship Task 3

# %% [markdown]
# # Importing necessary packages

# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %% [markdown]
# # Load Data

# %%
col_names = ['Id','SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm','Species']
data = pd.read_csv("Iris (1).csv", header=None, names=col_names)

# %% [markdown]
# # View Data Frame

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   1            5.1           3.5            1.4           0.2  Iris-setosa
# 2   2            4.9           3.0            1.4           0.2  Iris-setosa
# 3   3            4.7           3.2            1.3           0.2  Iris-setosa
# 4   4            4.6           3.1            1.5           0.2  Iris-setosa

# %% [markdown]
# # split dataset in features and target variable

# %%
feature_cols = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
X = data[feature_cols] # Features
X = X[1:]
y = data.Species # Target variable
y = y[1:]

# %% [markdown]
# # Split dataset into training set and test set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %% [markdown]
# # Building Decision Tree Model

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %% [markdown]
# # Evaluating Model

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9555555555555556

# %% [markdown]
# # Importing Data Visualizing packages

# %%
import matplotlib.pyplot as plt
from sklearn import tree

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=feature_cols,  
                   class_names="Species",
                   filled=True)
